# %% [markdown]
# <a href="https://colab.research.google.com/github/shivendr7/SatGAN/blob/master/EEGAN_5_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import matplotlib.pyplot as plt
from os import listdir
from keras.preprocessing.image import load_img, img_to_array
import numpy as np
from tensorflow.keras.utils import get_file
from tensorflow.io import read_file
from skimage import data, color
from skimage.transform import resize
url='http://efrosgans.eecs.berkeley.edu/pix2pix/datasets/maps.tar.gz'
path_to_zip=get_file('maps.tar.gz', origin=url, extract=True)
inside_train=listdir('/root/.keras/datasets/maps/train')
src_list=[]
full_path='/root/.keras/datasets/maps/train/'
for filename in inside_train:
  pixels=load_img(full_path+filename, target_size=(256,512))
  pixels=img_to_array(pixels)
  src_list.append(pixels[:,:256])
src_list=np.asarray(src_list)
resized_list=[]
for i in src_list:
  image=i
  image_resized = resize(image, (image.shape[0] // 2, image.shape[1] // 2),
                        anti_aliasing=True)
  resized_list.append(image_resized)
resized_list=np.array(resized_list)
plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
plt.imshow(src_list[0].astype('uint8'))
plt.subplot(1,2,2)
plt.imshow(resized_list[0].astype('uint8'))
# Out:
# Downloading data from http://efrosgans.eecs.berkeley.edu/pix2pix/datasets/maps.tar.gz
# 250249216/250242400 [==============================] - 103s 0us/step
# 250257408/250242400 [==============================] - 103s 0us/step

# %%
resized_list=(resized_list-127.5)/127.5
src_list=(src_list-127.5)/127.5

# %%
from tensorflow.keras.layers import Conv2D, Input, LeakyReLU, Concatenate, Lambda, Subtract, Add, Activation, Reshape, Multiply, Flatten, Dropout, Dense, BatchNormalization, Permute
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from keras.utils.vis_utils import plot_model
from tensorflow.keras.initializers import RandomNormal, Ones
import tensorflow as tf
from keras.losses import MeanSquaredError, MeanAbsolutePercentageError
import keras.backend as K
import numpy as np
from keras.models import model_from_json

# %%
def dense_block(in_layer):
  init=RandomNormal(stddev=0.2)
  conv1=Conv2D(filters=16, kernel_size=(3,3), padding='same', kernel_initializer='he_uniform', activation='relu')(in_layer)
  conv11=Conv2D(filters=16, kernel_size=(3,3), padding='same', kernel_initializer='he_uniform', activation='relu')(conv1)
  conv12=Conv2D(filters=16, kernel_size=(3,3), padding='same', kernel_initializer='he_uniform', activation='relu')(conv1)
  conv13=Conv2D(filters=16, kernel_size=(3,3), padding='same', kernel_initializer='he_uniform', activation='relu')(conv1)
  concat1=Concatenate()([conv11, conv12, conv13])
  conv201=Concatenate()([concat1, conv11])
  conv202=Concatenate()([concat1, conv12])
  conv203=Concatenate()([concat1, conv13])
  conv21i=Conv2D(filters=16, kernel_size=(1,1), padding='same', kernel_initializer='he_uniform', activation='relu')(conv201)
  conv22i=Conv2D(filters=16, kernel_size=(1,1), padding='same', kernel_initializer='he_uniform', activation='relu')(conv202)
  conv23i=Conv2D(filters=16, kernel_size=(1,1), padding='same', kernel_initializer='he_uniform', activation='relu')(conv203)
  conv21=Conv2D(filters=16, kernel_size=(3,3), padding='same', kernel_initializer='he_uniform', activation='relu')(conv21i)
  conv22=Conv2D(filters=16, kernel_size=(3,3), padding='same', kernel_initializer='he_uniform', activation='relu')(conv22i)
  conv23=Conv2D(filters=16, kernel_size=(3,3), padding='same', kernel_initializer='he_uniform', activation='relu')(conv23i)
  concat2=Concatenate()([conv21, conv22, conv23])
  conv301=Concatenate()([concat2, conv21i])
  conv302=Concatenate()([concat2, conv22i])
  conv303=Concatenate()([concat2, conv23i])
  conv31i=Conv2D(filters=16, kernel_size=(1,1), padding='same', kernel_initializer='he_uniform', activation='relu')(conv301)
  conv32i=Conv2D(filters=16, kernel_size=(1,1), padding='same', kernel_initializer='he_uniform', activation='relu')(conv302)
  conv33i=Conv2D(filters=16, kernel_size=(1,1), padding='same', kernel_initializer='he_uniform', activation='relu')(conv303)
  conv31=Conv2D(filters=16, kernel_size=(3,3), padding='same', kernel_initializer='he_uniform', activation='relu')(conv31i)
  conv32=Conv2D(filters=16, kernel_size=(3,3), padding='same', kernel_initializer='he_uniform', activation='relu')(conv32i)
  conv33=Conv2D(filters=16, kernel_size=(3,3), padding='same', kernel_initializer='he_uniform', activation='relu')(conv33i)
  concat3=Concatenate()([conv31, conv32, conv33])
  conv401=Concatenate()([concat3, conv31i])
  conv402=Concatenate()([concat3, conv32i])
  conv403=Concatenate()([concat3, conv33i])
  conv41i=Conv2D(filters=16, kernel_size=(1,1), padding='same', kernel_initializer='he_uniform', activation='relu')(conv401)
  conv42i=Conv2D(filters=16, kernel_size=(1,1), padding='same', kernel_initializer='he_uniform', activation='relu')(conv402)
  conv43i=Conv2D(filters=16, kernel_size=(1,1), padding='same', kernel_initializer='he_uniform', activation='relu')(conv403)
  concat4=Concatenate()([conv41i, conv42i, conv43i])
  out_layer=Concatenate()([concat4, conv1])
  return out_layer

# %%
def SubpixelConv2D(input_shape, scale=4):
    """
    Keras layer to do subpixel convolution.
    NOTE: Tensorflow backend only. Uses tf.depth_to_space
    Ref:
        [1] Real-Time Single Image and Video Super-Resolution Using an Efficient Sub-Pixel Convolutional Neural Network
            Shi et Al.
            https://arxiv.org/abs/1609.05158
    :param input_shape: tensor shape, (batch, height, width, channel)
    :param scale: upsampling scale. Default=4
    :return:
    """
    # upsample using depth_to_space
    def subpixel_shape(input_shape):
        dims = [input_shape[0],
                input_shape[1] * scale,
                input_shape[2] * scale,
                int(input_shape[3] / (scale ** 2))]
        output_shape = tuple(dims)
        return output_shape

    def subpixel(x):
        return tf.nn.depth_to_space(x, scale)

    return Lambda(subpixel, output_shape=subpixel_shape, name='subpixel')

# %%
def build_udsn(image_shape):
  inp=Input(shape=image_shape)
  db1=dense_block(inp)
  con=Concatenate()([db1, db1])
  db2=dense_block(con)
  con=Concatenate()([db1, db2, db2])
  db3=dense_block(con)
  con=Concatenate()([db1, db2, db3, db3])
  db4=dense_block(con)
  con=Concatenate()([db1, db2, db3, db4, db4])
  db5=dense_block(con)
  con=Concatenate()([db1, db2, db3, db4, db5, db5])
  db6=dense_block(con)
  sub_net=Conv2D(filters=64, kernel_size=(4,4), padding='same', activation='relu', kernel_initializer='he_uniform')(db6)
  sub_net=Conv2D(filters=64, kernel_size=(3,3), padding='same', activation='relu', kernel_initializer='he_uniform')(sub_net)
  sub_net=Conv2D(filters=32, kernel_size=(3,3), padding='same', activation='relu', kernel_initializer='he_uniform')(sub_net)
  LR=Conv2D(filters=12, kernel_size=(3,3), padding='same')(sub_net)
  LR=LeakyReLU(alpha=0.02)(LR)
  Ibase=SubpixelConv2D(LR.shape, scale=2)(LR)
  Ibase=BatchNormalization(momentum=0.8)(Ibase)
  Ibase=Activation('tanh')(Ibase)
  model=Model(inputs=inp, outputs=Ibase)
  return model

# %%
#eesn essentials
def meanfilter(shape, dtype=None):   #kernel to find mean of 3-channel pixel data
  f=np.array([
              [[[.3333],
                [.3333],
                [.33333]]]
  ])
  return K.variable(f, dtype='float32')
def laplacian(shape, dtype=None):   #laplacian kernel
  f=np.array([
      [[[-1]],[[-1]],[[-1]]],
      [[[-1]],[[ 8]],[[-1]]],
      [[[-1]],[[-1]],[[-1]]]
  ])
  return K.variable(f, dtype='float32')
def channel_thrice(shape, dtype=None):   #kernel to triplicate the single channel data
  f=np.array([
              [[[1, 1, 1]]]   #3 for three layers of filters
  ])
  return K.variable(f, dtype='float32')

# %%
def build_eesn(Ibase_shape):
  inp=Input(shape=(Ibase_shape))
  bw=Conv2D(filters=1, kernel_size=(1,1), padding='same', kernel_initializer=meanfilter, trainable=False)(inp)  #no change recommended   
  Iedge=Conv2D(filters=1, kernel_size=(3,3), padding='same', kernel_initializer=laplacian, trainable=False)(bw)     #no change recommended
  Itrip=Conv2D(filters=3, kernel_size=(1,1), padding='same', kernel_initializer=channel_thrice, trainable=False)(Iedge)   #no change recommended
  
  sub=Subtract()([inp, Itrip])
  ee=Conv2D(filters=32, kernel_size=(3,3), padding='same', strides=(2,2))(Iedge)
  ee=Conv2D(filters=64, kernel_size=(3,3), padding='same')(ee)
  ee=Conv2D(filters=16, kernel_size=(1,1), padding='same')(ee)
  
  #dense net
  db=dense_block(ee)
  db=dense_block(db)
  db=dense_block(db)
  db=Conv2D(16, kernel_size=(3,3), padding='same')(db)

  #mask branch
  mb=Conv2D(filters=16, kernel_size=(3,3), padding='same')(ee)
  mb=LeakyReLU(alpha=0.02)(mb)
  mb=Conv2D(filters=32, kernel_size=(3,3), padding='same')(mb)
  mb=LeakyReLU(alpha=0.02)(mb)
  mb=Conv2D(filters=16, kernel_size=(3,3), padding='same')(mb)
  mb=LeakyReLU(alpha=0.02)(mb)
  mb=Activation('sigmoid')(mb)

  #transpose=Permute((2,1,3), input_shape=db.shape)(db)
  product=Multiply()([db, mb])  #multiplies element wise
  #con=Concatenate()([mb, db])
  #transpose2=Permute((2,1,3), input_shape=product.shape)(product)
  sub_net=Conv2D(filters=64, kernel_size=(4,4), padding='same', activation='relu', kernel_initializer='he_uniform')(product)
  sub_net=Conv2D(filters=64, kernel_size=(3,3), padding='same', activation='relu', kernel_initializer='he_uniform')(sub_net)
  sub_net=Conv2D(filters=32, kernel_size=(3,3), padding='same', activation='relu', kernel_initializer='he_uniform')(sub_net)
  ee=Conv2D(4, kernel_size=(3,3), padding='same')(sub_net)
  Istedge=SubpixelConv2D(ee.shape, scale=2)(ee)
  #Istedge=Conv2D(1, kernel_size=(3,3), padding='same')(Istedge)
  Istedge=Conv2D(filters=3, kernel_size=(1,1), padding='same', kernel_initializer=channel_thrice, trainable=False)(Istedge)  #no change recommended
  
  #Istedge=BatchNormalization()(Istedge)
  SR=Add()([Istedge, sub])
  SR=BatchNormalization()(SR)
  SR=Activation('tanh')(SR)
  
  model=Model(inputs=inp, outputs=SR)
  return model

# %%
def consistency_loss(y_true, y_pred):
  lambd=5
  return charbonnier_penalty(y_true, y_pred)

mape=MeanAbsolutePercentageError()
def consistency_model(img_shape):
  inp=Input(shape=img_shape)
  Ibase=udsn(inp)
  ISR=eesn(Ibase)
  model=Model(inputs=inp, outputs=ISR)
  opt=Adam(learning_rate=0.00002, beta_1=0.5)
  model.compile(loss='mse', optimizer=opt)
  return model

# %%
from keras.applications.vgg16 import VGG16
vgg=VGG16(weights='imagenet', input_shape=(256,256,3), include_top=False)
vgg.trainable=False
#resize_layer=Conv2D(filters=3, kernel_size=(33,33), kernel_initializer=Ones(), trainable=False)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 1s 0us/step
# 58900480/58889256 [==============================] - 1s 0us/step

# %%
def charbonnier_penalty(y_true, y_pred):
  epsilon=0.001 #compensation parameter
  return K.mean(Subtract()([y_true, y_pred])**2 + epsilon**2)
  #return K.mean(K.square(y_true- y_pred) + epsilon**2)

def charbonnier_model(img_shape):
  inp=Input(shape=img_shape)
  Ibase=udsn(inp)
  #resize_Ibase=resize_layer(Ibase)
  out=vgg(Ibase*127.5+127.5)/10
  model=Model(inputs=inp, outputs=out)
  opt=Adam(learning_rate=0.00002, beta_1=0.5, clipnorm=1)
  model.compile(loss='mse', optimizer=opt)
  return model

# %%
def build_discriminator(img_shape):
  def block(Input, k, n, s):
    l1=Conv2D(n, kernel_size=(k,k), strides=(s,s), padding='same')(Input)
    Bn=BatchNormalization()(l1)
    Lrlu=LeakyReLU(alpha=0.02)(Bn)
    return Lrlu
  I1=Input(shape=img_shape)
  c1=Conv2D(64, kernel_size=(3,3), padding='same')(I1)
  l1=LeakyReLU(alpha=0.02)(c1)
  b1=block(l1, 3, 64, 2)
  b2=block(b1, 3, 128, 1)
  b3=block(b2, 3, 128,2)
  b4=block(b3, 3, 256, 1)
  b5=block(b4, 3, 256, 2)
  #b6=block(b5, 3, 512, 1)
  #b7=block(b6, 3, 512, 2)
  b8=Flatten()(b5)
  b9=Dropout(.1)(b8)
  l8=Dense(1024)(b9)
  b10=Dropout(.025)(l8)
  l9=LeakyReLU(alpha=0.02)(b10)
  l10=Dense(1, activation='sigmoid')(l9)
  m=Model(inputs=I1, outputs=l10)
  opt=Adam(learning_rate=0.000002, beta_1=0.5, clipnorm=1) #+1z 
  m.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])
  return m

# %%
def build_gan(img_shape):
  inp=Input(shape=img_shape)
  Ibase=udsn(inp)
  ISR=eesn(Ibase)
  out=disc(ISR)
  disc.trainable=False
  model=Model(inputs=inp, outputs=out)
  opt=Adam(learning_rate=0.00002, beta_1=0.1, clipnorm=1)
  model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])
  return model

# %%
udsn=build_udsn(image_shape=(128,128,3))
#plot_model(udsn)

# %%
eesn=build_eesn(Ibase_shape=(256,256,3))
#plot_model(eesn)

# %%
charb=charbonnier_model(img_shape=(128,128,3))
#charb.summary()

# %%
cons_model=consistency_model(img_shape=(128,128,3))
#cons_model.summary()

# %%
disc=build_discriminator(img_shape=(256,256,3))
#disc.summary()

# %%
gan=build_gan(img_shape=(128,128,3))
#gan.summary()

# %%
def train_charbonnier_model(n_batch):
  ix=np.random.randint(0, 1096, n_batch)
  input_batch=resized_list[ix]
  HR_batch=src_list[ix]
  #input_batch=input_batch*127.5+127.5
  HR_batch=HR_batch*127.5+127.5
  #extracting HR Image features through VGG
  #HR_resized=resize_layer(HR_batch)
  ground_feat=vgg(HR_batch)/10

  #print(input_batch.shape)
  
  loss, acc=charb.train_on_batch(input_batch, ground_feat), 0
  return loss, acc

# %%
def train_consistency_model(n_batch):
  ix=np.random.randint(0, 1096, n_batch)
  input_batch=resized_list[ix]
  HR_batch=src_list[ix]

  loss, acc=cons_model.train_on_batch(input_batch, HR_batch), 0
  return loss, acc

# %%
def generate_real_samples(n_batch):
  ix=np.random.randint(0, 1096, n_batch)
  HR_batch=src_list[ix]
  y_real=np.ones(shape=(n_batch,))
  return HR_batch, y_real

def generate_fake_samples(n_batch):
  ix=np.random.randint(0, 1096, n_batch)
  LR_batch=resized_list[ix]
  HR_batch_fake=eesn(udsn(LR_batch))
  y_fake=np.zeros(shape=(n_batch,))
  return HR_batch_fake, y_fake

# %%
def train(n_epochs=20, n_batch=2):
  half_batch=n_batch//2
  for i in range(n_epochs):
    ix=np.random.randint(0, 1096, n_batch)
    LR_batch=resized_list[ix]
    HR_batch=src_list[ix]
    
    #charb_loss, cons_loss=0, 0
    charb_loss, charb_acc=train_charbonnier_model(half_batch)
    cons_loss, cons_acc=train_consistency_model(half_batch)

    real_batch, y_real=generate_real_samples(half_batch)
    fake_batch, y_fake=generate_fake_samples(half_batch)

    disc_loss_real, disc_acc_real=disc.train_on_batch(real_batch, y_real)
    disc_loss_fake, disc_acc_fake=disc.train_on_batch(fake_batch, y_fake)

    false_positives=np.ones(shape=(n_batch,))
    gan_loss, gan_acc= gan.train_on_batch(LR_batch, false_positives)

    print('%d charb_loss[%.6f] cons_loss[%.6f] disc_loss_real[%.6f] disc_loss_fake[%.6f] gan_loss[%.6f]'%(i+1, charb_loss, cons_loss, disc_loss_real, 
                                                                                                          disc_loss_fake, gan_loss))

# %%
train(1000, 2)
# Out:
# 1 charb_loss[0.390531] cons_loss[0.267074] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[11.272434]
# 2 charb_loss[0.260360] cons_loss[0.228167] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[6.094054]
# 3 charb_loss[0.353968] cons_loss[0.267750] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[6.764441]
# 4 charb_loss[0.603217] cons_loss[0.303254] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[11.554520]
# 5 charb_loss[0.467340] cons_loss[0.271318] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[12.146762]
# 6 charb_loss[0.399210] cons_loss[0.297760] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[10.885383]
# 7 charb_loss[0.419646] cons_loss[0.299682] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[8.895729]
# 8 charb_loss[0.303397] cons_loss[0.353813] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[15.326750]
# 9 charb_loss[0.653676] cons_loss[0.233434] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[13.173279]
# 10 charb_loss[0.502188] cons_loss[0.225735] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[12.117414]
# 11 charb_loss[0.412143] cons_loss[0.360639] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[14.132483]
# 12 charb_loss[0.160398] cons_loss[0.162379] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[13.358194]
# 13 charb_loss[0.510468] cons_loss[0.175735] disc_loss_real[0.000007] disc_loss_fake[0.000000] gan_loss[12.418561]
# 14 charb_loss[0.539343] cons_loss[0.237750] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[10.665854]
# 15 charb_loss[0.183369] cons_loss[0.184540] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[11.830286]
# 16 charb_loss[0.313947] cons_loss[0.231773] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[11.211578]
# 17 charb_loss[0.404322] cons_loss[0.198762] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[10.628430]
# 18 charb_loss[0.081776] cons_loss[0.202717] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[9.014264]
# 19 charb_loss[0.511286] cons_loss[0.335001] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[10.950516]
# 20 charb_loss[0.555588] cons_loss[0.320217] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[10.476686]
# 21 charb_loss[0.195428] cons_loss[0.222646] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[8.974198]
# 22 charb_loss[0.321748] cons_loss[0.471765] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[14.017513]
# 23 charb_loss[0.362139] cons_loss[0.232060] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[12.520773]
# 24 charb_loss[0.281853] cons_loss[0.400833] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[10.798335]
# 25 charb_loss[0.497536] cons_loss[0.231827] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[9.654202]
# 26 charb_loss[0.539306] cons_loss[0.160657] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[7.995918]
# 27 charb_loss[0.032527] cons_loss[0.253243] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[10.984740]
# 28 charb_loss[0.251317] cons_loss[0.388046] disc_loss_real[0.000001] disc_loss_fake[0.000000] gan_loss[8.117620]
# 29 charb_loss[0.032144] cons_loss[0.183939] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[11.697534]
# 30 charb_loss[0.264118] cons_loss[0.332490] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[11.321639]
# 31 charb_loss[0.418849] cons_loss[0.262036] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[15.328857]
# 32 charb_loss[0.158254] cons_loss[0.208369] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[13.187469]
# 33 charb_loss[0.378476] cons_loss[0.236702] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[10.864246]
# 34 charb_loss[0.426920] cons_loss[0.194424] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[8.433183]
# 35 charb_loss[0.649305] cons_loss[0.336795] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[15.796650]
# 36 charb_loss[0.283520] cons_loss[0.238427] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[12.139908]
# 37 charb_loss[0.415029] cons_loss[0.234885] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[8.827715]
# 38 charb_loss[0.239860] cons_loss[0.243106] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[13.914117]
# 39 charb_loss[0.723611] cons_loss[0.382652] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[10.764879]
# 40 charb_loss[0.472174] cons_loss[0.242792] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[8.423668]
# 41 charb_loss[0.554950] cons_loss[0.156968] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[11.244500]
# 42 charb_loss[0.410687] cons_loss[0.322231] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[9.733379]
# 43 charb_loss[0.127912] cons_loss[0.358554] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[15.605188]
# 44 charb_loss[0.610476] cons_loss[0.232477] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[13.093556]
# 45 charb_loss[0.429550] cons_loss[0.226802] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[10.816045]
# 46 charb_loss[0.344792] cons_loss[0.235113] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[11.720079]
# 47 charb_loss[0.175502] cons_loss[0.239211] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[5.970955]
# 48 charb_loss[0.278854] cons_loss[0.270896] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[7.373952]
# 49 charb_loss[0.185468] cons_loss[0.210144] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[12.115078]
# 50 charb_loss[0.318525] cons_loss[0.236787] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[10.470432]
# 51 charb_loss[0.235324] cons_loss[0.235571] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[7.646873]
# 52 charb_loss[0.570524] cons_loss[0.246090] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[9.522473]
# 53 charb_loss[0.373758] cons_loss[0.193182] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[6.565217]
# 54 charb_loss[0.681821] cons_loss[0.209227] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[5.277932]
# 55 charb_loss[0.500537] cons_loss[0.096529] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[4.792846]
# 56 charb_loss[0.277019] cons_loss[0.193728] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[4.488281]
# 57 charb_loss[0.412204] cons_loss[0.244698] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[7.892371]
# 58 charb_loss[0.415360] cons_loss[0.211644] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[9.398611]
# 59 charb_loss[0.612590] cons_loss[0.200522] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[8.306260]
# 60 charb_loss[0.407077] cons_loss[0.192414] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[8.605059]
# 61 charb_loss[0.502864] cons_loss[0.378171] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[6.465640]
# 62 charb_loss[0.037578] cons_loss[0.174668] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[7.456179]
# 63 charb_loss[0.291451] cons_loss[0.277884] disc_loss_real[0.000000] disc_loss_fake[0.000002] gan_loss[9.003556]
# 64 charb_loss[0.392426] cons_loss[0.197855] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[5.157598]
# 65 charb_loss[0.419656] cons_loss[0.227415] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[4.386602]
# 66 charb_loss[0.671442] cons_loss[0.264345] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[6.050585]
# 67 charb_loss[0.419209] cons_loss[0.445521] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[5.705063]
# 68 charb_loss[0.241957] cons_loss[0.228023] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[6.861797]
# 69 charb_loss[0.533873] cons_loss[0.287207] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[8.246242]
# 70 charb_loss[0.351618] cons_loss[0.170579] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[5.933305]
# 71 charb_loss[0.177035] cons_loss[0.263839] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[8.653285]
# 72 charb_loss[0.683021] cons_loss[0.340112] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[9.694794]
# 73 charb_loss[0.565811] cons_loss[0.251524] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[7.988013]
# 74 charb_loss[0.561461] cons_loss[0.230307] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[6.413202]
# 75 charb_loss[0.443088] cons_loss[0.348786] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[9.031389]
# 76 charb_loss[0.304264] cons_loss[0.166672] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[7.089525]
# 77 charb_loss[0.059902] cons_loss[0.193876] disc_loss_real[0.000000] disc_loss_fake[0.004887] gan_loss[22.769085]
# 78 charb_loss[0.544941] cons_loss[0.221013] disc_loss_real[0.000026] disc_loss_fake[0.000000] gan_loss[40.639408]
# 79 charb_loss[0.741253] cons_loss[0.243148] disc_loss_real[4.839105] disc_loss_fake[0.000000] gan_loss[24.026741]
# 80 charb_loss[0.275567] cons_loss[0.164465] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[15.804478]
# 81 charb_loss[0.246138] cons_loss[0.493754] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[12.095546]
# 82 charb_loss[0.519860] cons_loss[0.336525] disc_loss_real[0.000002] disc_loss_fake[0.000000] gan_loss[15.626921]
# 83 charb_loss[0.485394] cons_loss[0.172876] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[14.300561]
# 84 charb_loss[0.627059] cons_loss[0.224271] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[17.993652]
# 85 charb_loss[0.589611] cons_loss[0.348184] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[16.668856]
# 86 charb_loss[0.324047] cons_loss[0.392994] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[15.924168]
# 87 charb_loss[0.319766] cons_loss[0.190144] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[14.101030]
# 88 charb_loss[0.251322] cons_loss[0.226010] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[16.106657]
# 89 charb_loss[0.323849] cons_loss[0.378277] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[14.699098]
# 90 charb_loss[0.264068] cons_loss[0.195281] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[13.856985]
# 91 charb_loss[0.595055] cons_loss[0.229576] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[14.975283]
# 92 charb_loss[0.894853] cons_loss[0.240022] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[20.613695]
# 93 charb_loss[0.781131] cons_loss[0.399180] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[11.073982]
# 94 charb_loss[0.301885] cons_loss[0.272159] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[14.255048]
# 95 charb_loss[0.458216] cons_loss[0.257997] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[21.675674]
# 96 charb_loss[0.296619] cons_loss[0.326711] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[17.094053]
# 97 charb_loss[0.515775] cons_loss[0.321149] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[15.328045]
# 98 charb_loss[0.453138] cons_loss[0.135260] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[15.914349]
# 99 charb_loss[0.305806] cons_loss[0.234586] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[13.793263]
# 100 charb_loss[0.452255] cons_loss[0.242175] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[8.895973]
# 101 charb_loss[0.712551] cons_loss[0.240186] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[6.528812]
# 102 charb_loss[0.448362] cons_loss[0.400543] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[12.516293]
# 103 charb_loss[0.537302] cons_loss[0.331905] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[11.867596]
# 104 charb_loss[0.512954] cons_loss[0.368281] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[17.286663]
# 105 charb_loss[0.321417] cons_loss[0.198943] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[18.012609]
# 106 charb_loss[0.430435] cons_loss[0.224043] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[16.530422]
# 107 charb_loss[0.408330] cons_loss[0.350640] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[16.529320]
# 108 charb_loss[0.584910] cons_loss[0.488023] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[12.537496]
# 109 charb_loss[0.438348] cons_loss[0.352623] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[10.218736]
# 110 charb_loss[0.392448] cons_loss[0.230005] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[7.881522]
# 111 charb_loss[0.028348] cons_loss[0.227477] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[17.509945]
# 112 charb_loss[0.409169] cons_loss[0.233926] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[12.241070]
# 113 charb_loss[0.246057] cons_loss[0.254711] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[11.765396]
# 114 charb_loss[0.335272] cons_loss[0.256534] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[13.101617]
# 115 charb_loss[0.498611] cons_loss[0.219113] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[15.649612]
# 116 charb_loss[0.344989] cons_loss[0.358574] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[13.897247]
# 117 charb_loss[0.635274] cons_loss[0.246987] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[14.603850]
# 118 charb_loss[0.431223] cons_loss[0.258151] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[12.326900]
# 119 charb_loss[0.525475] cons_loss[0.172814] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[16.736767]
# 120 charb_loss[0.306794] cons_loss[0.255433] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[18.782356]
# 121 charb_loss[0.523253] cons_loss[0.312868] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[19.071970]
# 122 charb_loss[0.445483] cons_loss[0.201022] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[15.756931]
# 123 charb_loss[0.558353] cons_loss[0.287542] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[13.998555]
# 124 charb_loss[0.647311] cons_loss[0.227850] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[9.464729]
# 125 charb_loss[0.128340] cons_loss[0.321379] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[11.341110]
# 126 charb_loss[0.380662] cons_loss[0.407946] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[9.362463]
# 127 charb_loss[0.380731] cons_loss[0.255354] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[7.366964]
# 128 charb_loss[0.270350] cons_loss[0.223301] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[11.926453]
# 129 charb_loss[0.471558] cons_loss[0.235438] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[10.760137]
# 130 charb_loss[0.296423] cons_loss[0.234050] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[13.286880]
# 131 charb_loss[0.308351] cons_loss[0.227084] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[10.515332]
# 132 charb_loss[0.579064] cons_loss[0.361374] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[17.662403]
# 133 charb_loss[0.544126] cons_loss[0.199408] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[10.295618]
# 134 charb_loss[0.451278] cons_loss[0.237249] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[14.016424]
# 135 charb_loss[0.873373] cons_loss[0.251933] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[16.456184]
# 136 charb_loss[0.099159] cons_loss[0.284297] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[13.920728]
# 137 charb_loss[0.825787] cons_loss[0.272376] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[17.685295]
# 138 charb_loss[0.384980] cons_loss[0.316578] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[17.548500]
# 139 charb_loss[0.297483] cons_loss[0.223650] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[17.728273]
# 140 charb_loss[0.595190] cons_loss[0.270331] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[12.792223]
# 141 charb_loss[0.608823] cons_loss[0.204170] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[12.639893]
# 142 charb_loss[0.200511] cons_loss[0.188541] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[17.908112]
# 143 charb_loss[0.616927] cons_loss[0.243089] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[12.996473]
# 144 charb_loss[0.383391] cons_loss[0.224130] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[10.198086]
# 145 charb_loss[0.395063] cons_loss[0.242214] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[9.244754]
# 146 charb_loss[0.222788] cons_loss[0.282506] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[8.568737]
# 147 charb_loss[0.285480] cons_loss[0.297321] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[12.820703]
# 148 charb_loss[0.290007] cons_loss[0.233989] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[15.539780]
# 149 charb_loss[0.247781] cons_loss[0.294266] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[14.190489]
# 150 charb_loss[0.380040] cons_loss[0.216604] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[9.350241]
# 151 charb_loss[0.553560] cons_loss[0.383941] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[13.412395]
# 152 charb_loss[0.519445] cons_loss[0.088658] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[16.673141]
# 153 charb_loss[0.030352] cons_loss[0.180234] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[12.326809]
# 154 charb_loss[0.564343] cons_loss[0.271852] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[14.780439]
# 155 charb_loss[0.329793] cons_loss[0.438811] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[14.400407]
# 156 charb_loss[0.311107] cons_loss[0.212547] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[12.722722]
# 157 charb_loss[0.367180] cons_loss[0.229018] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[13.410043]
# 158 charb_loss[0.276683] cons_loss[0.301586] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[18.215439]
# 159 charb_loss[0.552884] cons_loss[0.199345] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[7.971648]
# 160 charb_loss[0.453917] cons_loss[0.333463] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[9.879267]
# 161 charb_loss[0.082350] cons_loss[0.218000] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[7.462648]
# 162 charb_loss[0.551442] cons_loss[0.288435] disc_loss_real[0.000003] disc_loss_fake[0.000000] gan_loss[6.779441]
# 163 charb_loss[0.677367] cons_loss[0.209917] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[13.157034]
# 164 charb_loss[0.375247] cons_loss[0.140149] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[8.786334]
# 165 charb_loss[0.488090] cons_loss[0.243341] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[7.031024]
# 166 charb_loss[0.198522] cons_loss[0.242305] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[10.361759]
# 167 charb_loss[0.692771] cons_loss[0.203126] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[7.037138]
# 168 charb_loss[0.425138] cons_loss[0.237870] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[8.021726]
# 169 charb_loss[0.614069] cons_loss[0.307944] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[8.385015]
# 170 charb_loss[0.747484] cons_loss[0.263876] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[11.583006]
# 171 charb_loss[0.324227] cons_loss[0.352286] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[9.835733]
# 172 charb_loss[0.249815] cons_loss[0.173810] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[9.495205]
# 173 charb_loss[0.348326] cons_loss[0.305865] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[12.488480]
# 174 charb_loss[0.158608] cons_loss[0.228175] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[6.811735]
# 175 charb_loss[0.450214] cons_loss[0.233596] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[4.047812]
# 176 charb_loss[0.536642] cons_loss[0.219352] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[0.977079]
# 177 charb_loss[0.078695] cons_loss[0.213752] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[11.996681]
# 178 charb_loss[0.667189] cons_loss[0.282342] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[9.453516]
# 179 charb_loss[0.247755] cons_loss[0.187451] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[10.840576]
# 180 charb_loss[0.472060] cons_loss[0.284409] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[6.602308]
# 181 charb_loss[0.180023] cons_loss[0.321490] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[7.374401]
# 182 charb_loss[0.445189] cons_loss[0.294391] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[13.844259]
# 183 charb_loss[0.126379] cons_loss[0.226083] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[13.789627]
# 184 charb_loss[0.403084] cons_loss[0.226830] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[13.561682]
# 185 charb_loss[0.479080] cons_loss[0.408678] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[11.100246]
# 186 charb_loss[0.570401] cons_loss[0.251240] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[10.525489]
# 187 charb_loss[0.583109] cons_loss[0.233597] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[7.252677]
# 188 charb_loss[0.138303] cons_loss[0.367841] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[6.418561]
# 189 charb_loss[0.319778] cons_loss[0.272974] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[8.516838]
# 190 charb_loss[0.374404] cons_loss[0.252025] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[11.741131]
# 191 charb_loss[0.307942] cons_loss[0.339258] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[9.195899]
# 192 charb_loss[0.827293] cons_loss[0.251034] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[9.169362]
# 193 charb_loss[0.472244] cons_loss[0.408437] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[12.404938]
# 194 charb_loss[0.371612] cons_loss[0.217843] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[6.715146]
# 195 charb_loss[0.489029] cons_loss[0.249860] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[10.821808]
# 196 charb_loss[0.511457] cons_loss[0.273616] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[7.371988]
# 197 charb_loss[0.227182] cons_loss[0.247194] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[7.659052]
# 198 charb_loss[0.352767] cons_loss[0.255459] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[6.753494]
# 199 charb_loss[0.690858] cons_loss[0.246858] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[9.903134]
# 200 charb_loss[0.574494] cons_loss[0.399682] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[16.768852]
# 201 charb_loss[0.560351] cons_loss[0.229920] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[11.269054]
# 202 charb_loss[0.350758] cons_loss[0.322921] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[11.935036]
# 203 charb_loss[0.496185] cons_loss[0.299195] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[10.394895]
# 204 charb_loss[0.239231] cons_loss[0.306163] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[9.898539]
# 205 charb_loss[0.098506] cons_loss[0.253896] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[11.421535]
# 206 charb_loss[0.390602] cons_loss[0.200138] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[10.318488]
# 207 charb_loss[0.738423] cons_loss[0.185964] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[9.374983]
# 208 charb_loss[0.450798] cons_loss[0.190106] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[4.734980]
# 209 charb_loss[0.458205] cons_loss[0.150687] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[7.487327]
# 210 charb_loss[0.293270] cons_loss[0.229728] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[8.957913]
# 211 charb_loss[0.249070] cons_loss[0.205667] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[10.314033]
# 212 charb_loss[0.659082] cons_loss[0.273551] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[8.371534]
# 213 charb_loss[0.357594] cons_loss[0.258508] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[7.204365]
# 214 charb_loss[0.249702] cons_loss[0.237846] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[8.027328]
# 215 charb_loss[0.028900] cons_loss[0.238377] disc_loss_real[0.000000] disc_loss_fake[0.000001] gan_loss[8.435636]
# 216 charb_loss[0.410009] cons_loss[0.160745] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[11.698643]
# 217 charb_loss[0.341854] cons_loss[0.300962] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[8.645353]
# 218 charb_loss[0.245413] cons_loss[0.236601] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[9.917268]
# 219 charb_loss[0.230703] cons_loss[0.240730] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[8.386159]
# 220 charb_loss[0.277642] cons_loss[0.305203] disc_loss_real[0.000002] disc_loss_fake[0.000000] gan_loss[3.029941]
# 221 charb_loss[0.269762] cons_loss[0.282561] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[2.922247]
# 222 charb_loss[0.114099] cons_loss[0.198470] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[4.497577]
# 223 charb_loss[0.787837] cons_loss[0.229810] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[4.411365]
# 224 charb_loss[0.240178] cons_loss[0.269625] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[5.234442]
# 225 charb_loss[0.631644] cons_loss[0.294592] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[9.623834]
# 226 charb_loss[0.030966] cons_loss[0.173543] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[10.207008]
# 227 charb_loss[0.269418] cons_loss[0.331762] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[10.386766]
# 228 charb_loss[0.405696] cons_loss[0.258901] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[10.374853]
# 229 charb_loss[0.447485] cons_loss[0.237107] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[17.494801]
# 230 charb_loss[0.609911] cons_loss[0.175629] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[11.480515]
# 231 charb_loss[0.326465] cons_loss[0.218343] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[7.912290]
# 232 charb_loss[0.174279] cons_loss[0.184627] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[9.246140]
# 233 charb_loss[0.355700] cons_loss[0.290660] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[8.961326]
# 234 charb_loss[0.348793] cons_loss[0.152766] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[6.613533]
# 235 charb_loss[0.307318] cons_loss[0.233692] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[10.331452]
# 236 charb_loss[0.576096] cons_loss[0.232071] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[4.976499]
# 237 charb_loss[0.676001] cons_loss[0.207410] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[6.643890]
# 238 charb_loss[0.091824] cons_loss[0.359343] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[7.365377]
# 239 charb_loss[0.591321] cons_loss[0.411733] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[7.573530]
# 240 charb_loss[0.544654] cons_loss[0.342130] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[4.247694]
# 241 charb_loss[0.269519] cons_loss[0.275194] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[7.502320]
# 242 charb_loss[0.358603] cons_loss[0.345630] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[8.359223]
# 243 charb_loss[0.226541] cons_loss[0.224957] disc_loss_real[0.000001] disc_loss_fake[0.000000] gan_loss[7.451293]
# 244 charb_loss[0.559975] cons_loss[0.228118] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[11.726631]
# 245 charb_loss[0.283446] cons_loss[0.182595] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[8.678223]
# 246 charb_loss[0.334756] cons_loss[0.263008] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[5.881050]
# 247 charb_loss[0.510368] cons_loss[0.292531] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[3.137330]
# 248 charb_loss[0.472356] cons_loss[0.216902] disc_loss_real[0.000001] disc_loss_fake[0.000000] gan_loss[2.849994]
# 249 charb_loss[0.275700] cons_loss[0.278001] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[7.358020]
# 250 charb_loss[0.502855] cons_loss[0.410648] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[7.834444]
# 251 charb_loss[0.453750] cons_loss[0.326226] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[10.876308]
# 252 charb_loss[0.340553] cons_loss[0.366075] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[8.318128]
# 253 charb_loss[0.459393] cons_loss[0.263277] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[7.581895]
# 254 charb_loss[0.498670] cons_loss[0.245036] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[4.408106]
# 255 charb_loss[0.835216] cons_loss[0.274495] disc_loss_real[0.000000] disc_loss_fake[0.000001] gan_loss[3.825229]
# 256 charb_loss[0.611211] cons_loss[0.221886] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[5.882835]
# 257 charb_loss[0.647303] cons_loss[0.257134] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[6.953121]
# 258 charb_loss[0.110641] cons_loss[0.241975] disc_loss_real[0.000000] disc_loss_fake[0.000024] gan_loss[11.530883]
# 259 charb_loss[0.205030] cons_loss[0.361164] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[5.267039]
# 260 charb_loss[0.117201] cons_loss[0.219943] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[3.115803]
# 261 charb_loss[0.172498] cons_loss[0.198718] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[4.471152]
# 262 charb_loss[0.106573] cons_loss[0.250501] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[2.904779]
# 263 charb_loss[0.378787] cons_loss[0.101534] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[2.764185]
# 264 charb_loss[0.371471] cons_loss[0.353233] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[8.547665]
# 265 charb_loss[0.417459] cons_loss[0.224206] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[7.086899]
# 266 charb_loss[0.256211] cons_loss[0.212272] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[5.580541]
# 267 charb_loss[0.356457] cons_loss[0.200530] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[3.603956]
# 268 charb_loss[0.596630] cons_loss[0.330508] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[6.941153]
# 269 charb_loss[0.549460] cons_loss[0.400298] disc_loss_real[0.000001] disc_loss_fake[0.000000] gan_loss[5.593089]
# 270 charb_loss[0.679348] cons_loss[0.203283] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[5.662690]
# 271 charb_loss[0.430516] cons_loss[0.252464] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[1.982726]
# 272 charb_loss[0.409809] cons_loss[0.323301] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[6.532016]
# 273 charb_loss[0.142270] cons_loss[0.215180] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[12.058331]
# 274 charb_loss[0.133836] cons_loss[0.148864] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[4.518686]
# 275 charb_loss[0.093580] cons_loss[0.253010] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[7.524033]
# 276 charb_loss[0.350379] cons_loss[0.264832] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[10.182751]
# 277 charb_loss[0.933378] cons_loss[0.231173] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[3.588445]
# 278 charb_loss[0.266822] cons_loss[0.268571] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[6.227983]
# 279 charb_loss[0.501102] cons_loss[0.356023] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[12.611730]
# 280 charb_loss[0.400571] cons_loss[0.175837] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[7.123085]
# 281 charb_loss[0.463427] cons_loss[0.244061] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[3.977503]
# 282 charb_loss[0.169264] cons_loss[0.254379] disc_loss_real[0.001399] disc_loss_fake[0.000000] gan_loss[0.023309]
# 283 charb_loss[0.440757] cons_loss[0.283361] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[0.000343]
# 284 charb_loss[0.218053] cons_loss[0.245677] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[0.000157]
# 285 charb_loss[0.384481] cons_loss[0.212552] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[0.115852]
# 286 charb_loss[0.406972] cons_loss[0.225296] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[0.004583]
# 287 charb_loss[0.585665] cons_loss[0.249475] disc_loss_real[0.000000] disc_loss_fake[0.000023] gan_loss[0.005162]
# 288 charb_loss[0.577529] cons_loss[0.229363] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[3.546643]
# 289 charb_loss[0.460876] cons_loss[0.194360] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[0.002308]
# 290 charb_loss[0.789572] cons_loss[0.353452] disc_loss_real[0.000000] disc_loss_fake[0.000031] gan_loss[0.016194]
# 291 charb_loss[0.099119] cons_loss[0.224424] disc_loss_real[0.000000] disc_loss_fake[0.000006] gan_loss[0.000141]
# 292 charb_loss[0.022102] cons_loss[0.213368] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[0.007794]
# 293 charb_loss[0.390994] cons_loss[0.376714] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[0.006716]
# 294 charb_loss[0.423342] cons_loss[0.233921] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[2.819499]
# 295 charb_loss[0.391209] cons_loss[0.174310] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[0.345580]
# 296 charb_loss[0.189800] cons_loss[0.209017] disc_loss_real[0.000000] disc_loss_fake[0.000020] gan_loss[0.014168]
# 297 charb_loss[0.224516] cons_loss[0.204723] disc_loss_real[0.000000] disc_loss_fake[0.000064] gan_loss[0.002684]
# 298 charb_loss[0.688214] cons_loss[0.369688] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[0.789737]
# 299 charb_loss[0.246679] cons_loss[0.351372] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[0.079157]
# 300 charb_loss[0.243127] cons_loss[0.221988] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[0.162991]
# 301 charb_loss[0.323670] cons_loss[0.233129] disc_loss_real[0.000000] disc_loss_fake[0.000001] gan_loss[0.002380]
# 302 charb_loss[0.831121] cons_loss[0.374843] disc_loss_real[0.000000] disc_loss_fake[0.000211] gan_loss[3.265268]
# 303 charb_loss[0.389061] cons_loss[0.189089] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[0.197974]
# 304 charb_loss[0.206605] cons_loss[0.178408] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[4.577088]
# 305 charb_loss[0.288224] cons_loss[0.248387] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[0.763874]
# 306 charb_loss[0.337057] cons_loss[0.185682] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[3.805060]
# 307 charb_loss[0.703476] cons_loss[0.140805] disc_loss_real[0.000000] disc_loss_fake[0.000027] gan_loss[7.791809]
# 308 charb_loss[0.344703] cons_loss[0.330226] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[4.242434]
# 309 charb_loss[0.558295] cons_loss[0.221956] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[3.302970]
# 310 charb_loss[0.538302] cons_loss[0.453508] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[1.727993]
# 311 charb_loss[0.385155] cons_loss[0.262533] disc_loss_real[0.000000] disc_loss_fake[0.000002] gan_loss[4.474620]
# 312 charb_loss[0.445904] cons_loss[0.481291] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[4.291455]
# 313 charb_loss[0.426832] cons_loss[0.272087] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[2.867989]
# 314 charb_loss[0.483494] cons_loss[0.426131] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[2.899400]
# 315 charb_loss[0.899704] cons_loss[0.235680] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[0.059644]
# 316 charb_loss[0.381661] cons_loss[0.352830] disc_loss_real[0.000000] disc_loss_fake[0.000003] gan_loss[4.855747]
# 317 charb_loss[0.242462] cons_loss[0.199144] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[1.522070]
# 318 charb_loss[0.241229] cons_loss[0.300763] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[7.133121]
# 319 charb_loss[0.322627] cons_loss[0.297373] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[3.577050]
# 320 charb_loss[1.070426] cons_loss[0.238885] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[3.974293]
# 321 charb_loss[0.345638] cons_loss[0.385072] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[1.090795]
# 322 charb_loss[0.726993] cons_loss[0.202286] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[0.145293]
# 323 charb_loss[0.402273] cons_loss[0.203421] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[0.263380]
# 324 charb_loss[0.584201] cons_loss[0.200706] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[3.306837]
# 325 charb_loss[0.660664] cons_loss[0.271133] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[4.061589]
# 326 charb_loss[0.420938] cons_loss[0.265726] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[3.151359]
# 327 charb_loss[0.416400] cons_loss[0.216447] disc_loss_real[0.000000] disc_loss_fake[0.000012] gan_loss[4.323101]
# 328 charb_loss[0.385113] cons_loss[0.318348] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[3.211274]
# 329 charb_loss[0.418380] cons_loss[0.301251] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[0.350245]
# 330 charb_loss[0.733082] cons_loss[0.275570] disc_loss_real[0.000000] disc_loss_fake[0.000006] gan_loss[0.021694]
# 331 charb_loss[0.494764] cons_loss[0.228634] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[1.006067]
# 332 charb_loss[0.477915] cons_loss[0.241962] disc_loss_real[0.000000] disc_loss_fake[0.000003] gan_loss[0.001478]
# 333 charb_loss[1.071005] cons_loss[0.261979] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[0.798222]
# 334 charb_loss[0.445530] cons_loss[0.209893] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[2.543030]
# 335 charb_loss[0.325247] cons_loss[0.169487] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[1.380181]
# 336 charb_loss[0.286989] cons_loss[0.271831] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[0.367726]
# 337 charb_loss[0.345045] cons_loss[0.230540] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[0.005799]
# 338 charb_loss[0.810581] cons_loss[0.286513] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[0.298284]
# 339 charb_loss[0.613202] cons_loss[0.268340] disc_loss_real[0.000000] disc_loss_fake[0.000001] gan_loss[0.893026]
# 340 charb_loss[0.666406] cons_loss[0.236318] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[2.108471]
# 341 charb_loss[0.513003] cons_loss[0.306151] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[2.846474]
# 342 charb_loss[0.479087] cons_loss[0.245662] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[2.099248]
# 343 charb_loss[0.585933] cons_loss[0.205572] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[5.041547]
# 344 charb_loss[0.541217] cons_loss[0.227988] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[3.893617]
# 345 charb_loss[0.526758] cons_loss[0.200615] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[0.092806]
# 346 charb_loss[0.155976] cons_loss[0.199872] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[1.594876]
# 347 charb_loss[0.411691] cons_loss[0.224889] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[0.053458]
# 348 charb_loss[0.787150] cons_loss[0.218741] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[2.156253]
# 349 charb_loss[0.169938] cons_loss[0.265118] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[3.539166]
# 350 charb_loss[0.223843] cons_loss[0.237169] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[0.356978]
# 351 charb_loss[0.477651] cons_loss[0.425653] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[0.459522]
# 352 charb_loss[0.820570] cons_loss[0.336840] disc_loss_real[0.000000] disc_loss_fake[0.000001] gan_loss[0.019628]
# 353 charb_loss[0.132636] cons_loss[0.324789] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[2.534294]
# 354 charb_loss[0.407881] cons_loss[0.297806] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[3.724692]
# 355 charb_loss[0.471750] cons_loss[0.272330] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[1.081177]
# 356 charb_loss[0.300406] cons_loss[0.302818] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[0.390253]
# 357 charb_loss[0.510916] cons_loss[0.475433] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[3.004198]
# 358 charb_loss[0.136366] cons_loss[0.431414] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[6.499045]
# 359 charb_loss[0.141178] cons_loss[0.193688] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[0.158871]
# 360 charb_loss[0.425043] cons_loss[0.206514] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[0.052638]
# 361 charb_loss[0.383905] cons_loss[0.239851] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[0.037764]
# 362 charb_loss[0.403407] cons_loss[0.307055] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[0.099271]
# 363 charb_loss[0.530511] cons_loss[0.236049] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[0.768730]
# 364 charb_loss[0.346177] cons_loss[0.312097] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[1.350052]
# 365 charb_loss[0.409687] cons_loss[0.221599] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[0.650045]
# 366 charb_loss[0.300025] cons_loss[0.192546] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[0.114253]
# 367 charb_loss[0.373141] cons_loss[0.233270] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[1.304534]
# 368 charb_loss[0.457584] cons_loss[0.380755] disc_loss_real[0.000000] disc_loss_fake[0.000001] gan_loss[0.421316]
# 369 charb_loss[0.478524] cons_loss[0.215304] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[0.026637]
# 370 charb_loss[0.215776] cons_loss[0.169186] disc_loss_real[0.000000] disc_loss_fake[0.000001] gan_loss[0.006286]
# 371 charb_loss[0.263044] cons_loss[0.378876] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[0.380094]
# 372 charb_loss[0.289223] cons_loss[0.223814] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[1.310996]
# 373 charb_loss[0.494738] cons_loss[0.174517] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[0.000037]
# 374 charb_loss[0.434557] cons_loss[0.205846] disc_loss_real[0.000000] disc_loss_fake[0.000010] gan_loss[1.932441]
# 375 charb_loss[0.637757] cons_loss[0.396483] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[3.552879]
# 376 charb_loss[0.104939] cons_loss[0.357022] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[1.730224]
# 377 charb_loss[0.810086] cons_loss[0.240894] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[0.896335]
# 378 charb_loss[0.405693] cons_loss[0.203109] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[0.784547]
# 379 charb_loss[0.490923] cons_loss[0.217473] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[2.721604]
# 380 charb_loss[0.393210] cons_loss[0.183700] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[2.514567]
# 381 charb_loss[0.482667] cons_loss[0.236930] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[2.379406]
# 382 charb_loss[0.578633] cons_loss[0.254316] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[0.055517]
# 383 charb_loss[0.128579] cons_loss[0.214970] disc_loss_real[0.000000] disc_loss_fake[0.000001] gan_loss[2.282880]
# 384 charb_loss[0.378610] cons_loss[0.181771] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[0.109321]
# 385 charb_loss[0.124145] cons_loss[0.178008] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[0.203214]
# 386 charb_loss[0.398704] cons_loss[0.219317] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[0.002265]
# 387 charb_loss[0.435218] cons_loss[0.159817] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[0.441561]
# 388 charb_loss[0.984815] cons_loss[0.247267] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[0.091855]
# 389 charb_loss[0.310788] cons_loss[0.218875] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[0.747489]
# 390 charb_loss[0.198194] cons_loss[0.183074] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[0.631426]
# 391 charb_loss[0.316019] cons_loss[0.189918] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[1.892099]
# 392 charb_loss[0.569086] cons_loss[0.204880] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[3.761816]
# 393 charb_loss[0.265187] cons_loss[0.210056] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[0.081682]
# 394 charb_loss[0.667280] cons_loss[0.230731] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[0.878252]
# 395 charb_loss[0.225419] cons_loss[0.237263] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[0.003762]
# 396 charb_loss[0.228149] cons_loss[0.148637] disc_loss_real[0.000000] disc_loss_fake[0.000020] gan_loss[0.018001]
# 397 charb_loss[0.442439] cons_loss[0.237673] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[1.294530]
# 398 charb_loss[0.460898] cons_loss[0.195510] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[1.471838]
# 399 charb_loss[0.267949] cons_loss[0.227650] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[0.772005]
# 400 charb_loss[0.549715] cons_loss[0.226808] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[0.122490]
# 401 charb_loss[0.366040] cons_loss[0.255986] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[0.060814]
# 402 charb_loss[0.438383] cons_loss[0.227181] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[4.278904]
# 403 charb_loss[0.443654] cons_loss[0.292228] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[1.732047]
# 404 charb_loss[0.402224] cons_loss[0.252509] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[1.172315]
# 405 charb_loss[0.324997] cons_loss[0.177983] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[0.166030]
# 406 charb_loss[0.578182] cons_loss[0.234637] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[1.316624]
# 407 charb_loss[0.086714] cons_loss[0.233604] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[2.154859]
# 408 charb_loss[0.326978] cons_loss[0.287652] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[0.386598]
# 409 charb_loss[0.449763] cons_loss[0.215488] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[0.466244]
# 410 charb_loss[0.402075] cons_loss[0.251780] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[0.014297]
# 411 charb_loss[0.318697] cons_loss[0.237252] disc_loss_real[0.000000] disc_loss_fake[0.000067] gan_loss[1.126164]
# 412 charb_loss[0.703372] cons_loss[0.248385] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[0.648237]
# 413 charb_loss[0.385346] cons_loss[0.246750] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[4.166618]
# 414 charb_loss[0.699237] cons_loss[0.241682] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[0.632309]
# 415 charb_loss[0.678136] cons_loss[0.292054] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[0.550683]
# 416 charb_loss[0.478365] cons_loss[0.199071] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[0.302551]
# 417 charb_loss[0.350461] cons_loss[0.238584] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[0.206356]
# 418 charb_loss[0.574134] cons_loss[0.240592] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[0.019080]
# 419 charb_loss[0.494217] cons_loss[0.354812] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[0.164617]
# 420 charb_loss[0.544670] cons_loss[0.337754] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[3.304377]
# ...
# 862 charb_loss[0.427828] cons_loss[0.229334] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[9.059973]
# 863 charb_loss[0.335176] cons_loss[0.336257] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[12.270412]
# 864 charb_loss[0.141093] cons_loss[0.287345] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[9.808284]
# 865 charb_loss[0.293111] cons_loss[0.175537] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[7.481350]
# 866 charb_loss[0.615490] cons_loss[0.214415] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[3.875483]
# 867 charb_loss[0.506727] cons_loss[0.244755] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[8.273529]
# 868 charb_loss[0.227698] cons_loss[0.191642] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[9.793899]
# 869 charb_loss[0.211448] cons_loss[0.386931] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[10.240720]
# 870 charb_loss[0.417727] cons_loss[0.315361] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[8.856258]
# 871 charb_loss[0.286744] cons_loss[0.218660] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[4.615674]
# 872 charb_loss[0.607546] cons_loss[0.237095] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[7.910479]
# 873 charb_loss[0.089780] cons_loss[0.229874] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[8.124784]
# 874 charb_loss[0.200514] cons_loss[0.234439] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[10.311988]
# 875 charb_loss[0.247549] cons_loss[0.239967] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[10.219055]
# 876 charb_loss[0.479334] cons_loss[0.211807] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[5.080596]
# 877 charb_loss[0.711553] cons_loss[0.257003] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[10.337342]
# 878 charb_loss[0.135247] cons_loss[0.242738] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[13.223099]
# 879 charb_loss[0.293108] cons_loss[0.204110] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[13.091974]
# 880 charb_loss[0.327499] cons_loss[0.332711] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[8.234555]
# 881 charb_loss[0.341299] cons_loss[0.267802] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[8.532113]
# 882 charb_loss[0.552682] cons_loss[0.395844] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[10.488559]
# 883 charb_loss[0.663520] cons_loss[0.187612] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[6.519844]
# 884 charb_loss[0.215088] cons_loss[0.187170] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[9.281333]
# 885 charb_loss[0.369487] cons_loss[0.173066] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[11.890362]
# 886 charb_loss[0.616787] cons_loss[0.169028] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[8.912157]
# 887 charb_loss[0.529476] cons_loss[0.371715] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[5.980811]
# 888 charb_loss[0.372229] cons_loss[0.237405] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[11.755537]
# 889 charb_loss[0.651209] cons_loss[0.217831] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[2.490008]
# 890 charb_loss[0.380083] cons_loss[0.325314] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[4.449732]
# 891 charb_loss[0.397308] cons_loss[0.238897] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[11.224892]
# 892 charb_loss[0.216614] cons_loss[0.222795] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[11.189183]
# 893 charb_loss[0.461643] cons_loss[0.261526] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[6.378657]
# 894 charb_loss[0.501580] cons_loss[0.343010] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[7.457011]
# 895 charb_loss[0.165177] cons_loss[0.222096] disc_loss_real[0.000000] disc_loss_fake[0.000040] gan_loss[11.443951]
# 896 charb_loss[0.336034] cons_loss[0.188596] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[7.523640]
# 897 charb_loss[0.258438] cons_loss[0.198806] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[9.715759]
# 898 charb_loss[0.373194] cons_loss[0.395782] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[14.532939]
# 899 charb_loss[0.338368] cons_loss[0.281687] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[15.296017]
# 900 charb_loss[0.243401] cons_loss[0.226442] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[6.864883]
# 901 charb_loss[0.431353] cons_loss[0.182292] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[9.393707]
# 902 charb_loss[0.305142] cons_loss[0.237759] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[6.420931]
# 903 charb_loss[0.479157] cons_loss[0.090872] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[8.874383]
# 904 charb_loss[0.420300] cons_loss[0.265996] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[10.927406]
# 905 charb_loss[0.111342] cons_loss[0.228742] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[9.755553]
# 906 charb_loss[0.802356] cons_loss[0.211766] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[5.606565]
# 907 charb_loss[0.305008] cons_loss[0.213228] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[7.776228]
# 908 charb_loss[0.260122] cons_loss[0.210203] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[9.479130]
# 909 charb_loss[0.372260] cons_loss[0.167328] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[3.890889]
# 910 charb_loss[0.279650] cons_loss[0.229312] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[2.478075]
# 911 charb_loss[0.418494] cons_loss[0.243252] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[3.668242]
# 912 charb_loss[0.340450] cons_loss[0.187272] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[6.968738]
# 913 charb_loss[0.469395] cons_loss[0.272396] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[12.144246]
# 914 charb_loss[0.250424] cons_loss[0.197934] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[10.551517]
# 915 charb_loss[0.779275] cons_loss[0.209277] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[9.160185]
# 916 charb_loss[0.393703] cons_loss[0.178374] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[10.180671]
# 917 charb_loss[0.626268] cons_loss[0.186253] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[10.578194]
# 918 charb_loss[0.344597] cons_loss[0.151462] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[7.111048]
# 919 charb_loss[0.521104] cons_loss[0.233598] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[6.367163]
# 920 charb_loss[0.269789] cons_loss[0.253488] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[3.660219]
# 921 charb_loss[0.322844] cons_loss[0.234958] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[4.372658]
# 922 charb_loss[0.477442] cons_loss[0.253269] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[3.106586]
# 923 charb_loss[0.320845] cons_loss[0.208140] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[6.276730]
# 924 charb_loss[0.544032] cons_loss[0.269296] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[8.919182]
# 925 charb_loss[0.232287] cons_loss[0.269460] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[11.149845]
# 926 charb_loss[0.508166] cons_loss[0.199342] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[8.113475]
# 927 charb_loss[0.299214] cons_loss[0.202080] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[9.303805]
# 928 charb_loss[0.763010] cons_loss[0.171223] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[5.316954]
# 929 charb_loss[0.364889] cons_loss[0.251016] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[1.373021]
# 930 charb_loss[0.309746] cons_loss[0.312039] disc_loss_real[0.000000] disc_loss_fake[0.000001] gan_loss[12.804279]
# 931 charb_loss[0.560112] cons_loss[0.331846] disc_loss_real[0.000000] disc_loss_fake[0.000011] gan_loss[17.999655]
# 932 charb_loss[0.415143] cons_loss[0.207020] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[6.092022]
# 933 charb_loss[0.849512] cons_loss[0.267914] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[16.811260]
# 934 charb_loss[0.273547] cons_loss[0.379351] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[14.024281]
# 935 charb_loss[0.379602] cons_loss[0.255793] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[6.765724]
# 936 charb_loss[0.274647] cons_loss[0.216627] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[7.939370]
# 937 charb_loss[0.328882] cons_loss[0.170681] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[7.999132]
# 938 charb_loss[0.250689] cons_loss[0.316205] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[13.477488]
# 939 charb_loss[0.308230] cons_loss[0.205885] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[6.497328]
# 940 charb_loss[0.475496] cons_loss[0.226374] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[5.688086]
# 941 charb_loss[0.315119] cons_loss[0.290898] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[8.136497]
# 942 charb_loss[0.448621] cons_loss[0.223525] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[15.676927]
# 943 charb_loss[0.375870] cons_loss[0.179842] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[12.162594]
# 944 charb_loss[0.588331] cons_loss[0.368697] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[7.528716]
# 945 charb_loss[0.706130] cons_loss[0.206714] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[5.804837]
# 946 charb_loss[0.141758] cons_loss[0.290320] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[3.329555]
# 947 charb_loss[0.282437] cons_loss[0.126831] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[3.708531]
# 948 charb_loss[0.458852] cons_loss[0.216529] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[11.746279]
# 949 charb_loss[0.684345] cons_loss[0.241265] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[6.316419]
# 950 charb_loss[0.110117] cons_loss[0.224475] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[9.192007]
# 951 charb_loss[0.204346] cons_loss[0.207784] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[5.549954]
# 952 charb_loss[0.317108] cons_loss[0.258687] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[6.067289]
# 953 charb_loss[0.191087] cons_loss[0.220265] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[12.011808]
# 954 charb_loss[0.179797] cons_loss[0.209600] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[9.157621]
# 955 charb_loss[0.518174] cons_loss[0.190679] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[8.086761]
# 956 charb_loss[0.609560] cons_loss[0.185103] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[8.557517]
# 957 charb_loss[0.324444] cons_loss[0.329461] disc_loss_real[0.000000] disc_loss_fake[0.000002] gan_loss[2.696758]
# 958 charb_loss[0.577613] cons_loss[0.325114] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[10.638235]
# 959 charb_loss[0.506095] cons_loss[0.247506] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[7.954819]
# 960 charb_loss[0.601606] cons_loss[0.263868] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[2.855841]
# 961 charb_loss[0.302903] cons_loss[0.482130] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[8.800486]
# 962 charb_loss[0.272922] cons_loss[0.213921] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[9.170566]
# 963 charb_loss[0.368866] cons_loss[0.209487] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[8.471004]
# 964 charb_loss[0.569323] cons_loss[0.302618] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[12.396547]
# 965 charb_loss[0.248996] cons_loss[0.386891] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[12.222486]
# 966 charb_loss[0.196666] cons_loss[0.266187] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[13.925746]
# 967 charb_loss[0.309583] cons_loss[0.361747] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[10.067229]
# 968 charb_loss[0.171995] cons_loss[0.188823] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[7.961432]
# 969 charb_loss[0.379638] cons_loss[0.195753] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[6.439152]
# 970 charb_loss[0.195579] cons_loss[0.352254] disc_loss_real[0.000000] disc_loss_fake[0.000001] gan_loss[7.204717]
# 971 charb_loss[0.119258] cons_loss[0.235496] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[0.859034]
# 972 charb_loss[0.468644] cons_loss[0.256793] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[12.062538]
# 973 charb_loss[0.363116] cons_loss[0.224333] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[10.434553]
# 974 charb_loss[0.283902] cons_loss[0.178827] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[6.063619]
# 975 charb_loss[0.359604] cons_loss[0.185828] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[5.588614]
# 976 charb_loss[0.295956] cons_loss[0.248928] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[7.305700]
# 977 charb_loss[0.371723] cons_loss[0.249150] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[4.036572]
# 978 charb_loss[0.170640] cons_loss[0.272156] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[10.377378]
# 979 charb_loss[0.026730] cons_loss[0.259154] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[8.746413]
# 980 charb_loss[0.267350] cons_loss[0.216162] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[12.350813]
# 981 charb_loss[0.460876] cons_loss[0.242164] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[8.290082]
# 982 charb_loss[0.678381] cons_loss[0.229303] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[5.933958]
# 983 charb_loss[0.257004] cons_loss[0.212586] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[5.904873]
# 984 charb_loss[0.373275] cons_loss[0.364959] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[3.270292]
# 985 charb_loss[0.183528] cons_loss[0.224648] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[5.636654]
# 986 charb_loss[0.317156] cons_loss[0.218309] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[6.103182]
# 987 charb_loss[0.296495] cons_loss[0.256550] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[2.122806]
# 988 charb_loss[0.574117] cons_loss[0.250497] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[8.922369]
# 989 charb_loss[0.575172] cons_loss[0.331306] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[13.457309]
# 990 charb_loss[0.519235] cons_loss[0.253106] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[14.618134]
# 991 charb_loss[0.501981] cons_loss[0.178146] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[8.729286]
# 992 charb_loss[0.460584] cons_loss[0.177108] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[3.670533]
# 993 charb_loss[0.391488] cons_loss[0.248973] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[5.410892]
# 994 charb_loss[0.352539] cons_loss[0.371234] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[7.704123]
# 995 charb_loss[0.088048] cons_loss[0.191099] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[3.936161]
# 996 charb_loss[0.254153] cons_loss[0.378026] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[10.363422]
# 997 charb_loss[0.465000] cons_loss[0.309377] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[9.142395]
# 998 charb_loss[0.316653] cons_loss[0.225111] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[5.950669]
# 999 charb_loss[0.279190] cons_loss[0.238334] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[12.349925]
# 1000 charb_loss[0.230031] cons_loss[0.229593] disc_loss_real[0.000000] disc_loss_fake[0.000000] gan_loss[9.013329]

# %%
#for i in range(1000):
#  print(i, train_charbonnier_model(1), train_consistency_model(1))

# %%
"""
from keras.applications.vgg16 import VGG16
vgg=VGG16(weights='imagenet', input_shape=(256,256,3), include_top=False)
vgg.trainable=False
#resize_layer=Conv2D(filters=3, kernel_size=(33,33), kernel_initializer=Ones(), trainable=False)
"""
# Out:
# "\nfrom keras.applications.vgg16 import VGG16\nvgg=VGG16(weights='imagenet', input_shape=(256,256,3), include_top=False)\nvgg.trainable=False\n#resize_layer=Conv2D(filters=3, kernel_size=(33,33), kernel_initializer=Ones(), trainable=False)\n"

# %%
"""
def charbonnier_penalty(y_true, y_pred):
  epsilon=0.001 #compensation parameter
  return K.mean(Subtract()([y_true, y_pred])**2 + epsilon**2)
  #return K.mean(K.square(y_true- y_pred) + epsilon**2)

def charbonnier_model(img_shape):
  inp=Input(shape=img_shape)
  Ibase=udsn(inp)
  #resize_Ibase=resize_layer(Ibase)
  out=vgg(Ibase*127.5+127.5)
  model=Model(inputs=inp, outputs=out)
  opt=Adam(learning_rate=0.002, beta_1=0.5, clipnorm=1)
  model.compile(loss='mse', optimizer=opt)
  return model
"""
# Out:
# "\ndef charbonnier_penalty(y_true, y_pred):\n  epsilon=0.001 #compensation parameter\n  return K.mean(Subtract()([y_true, y_pred])**2 + epsilon**2)\n  #return K.mean(K.square(y_true- y_pred) + epsilon**2)\n\ndef charbonnier_model(img_shape):\n  inp=Input(shape=img_shape)\n  Ibase=udsn(inp)\n  #resize_Ibase=resize_layer(Ibase)\n  out=vgg(Ibase*127.5+127.5)\n  model=Model(inputs=inp, outputs=out)\n  opt=Adam(learning_rate=0.002, beta_1=0.5, clipnorm=1)\n  model.compile(loss='mse', optimizer=opt)\n  return model\n"

# %%
"""
charb=charbonnier_model(img_shape=(128,128,3))
#charb.summary()
"""
# Out:
# '\ncharb=charbonnier_model(img_shape=(128,128,3))\n#charb.summary()\n'

# %%
"""
def train_charbonnier_model(n_batch):
  ix=np.random.randint(0, 1096, n_batch)
  input_batch=resized_list[ix]
  HR_batch=src_list[ix]
  #input_batch=input_batch*127.5+127.5
  HR_batch=HR_batch*127.5+127.5
  #extracting HR Image features through VGG
  #HR_resized=resize_layer(HR_batch)
  ground_feat=vgg(HR_batch)

  #print(input_batch.shape)
  
  loss, acc=charb.train_on_batch(input_batch, ground_feat), 0
  return loss, acc
"""
# Out:
# '\ndef train_charbonnier_model(n_batch):\n  ix=np.random.randint(0, 1096, n_batch)\n  input_batch=resized_list[ix]\n  HR_batch=src_list[ix]\n  #input_batch=input_batch*127.5+127.5\n  HR_batch=HR_batch*127.5+127.5\n  #extracting HR Image features through VGG\n  #HR_resized=resize_layer(HR_batch)\n  ground_feat=vgg(HR_batch)\n\n  #print(input_batch.shape)\n  \n  loss, acc=charb.train_on_batch(input_batch, ground_feat), 0\n  return loss, acc\n'

# %%
"""
for i in range(100):
  print(train_charbonnier_model(1))
"""
# Out:
# '\nfor i in range(100):\n  print(train_charbonnier_model(1))\n'

# %%
# save the models (EESN, UDSN, DISC)

todrive='drive/MyDrive/weights/'
# serialize weights to HDF5
udsn.save_weights(todrive + "udsn3000.h5")


# serialize weights to HDF5
eesn.save_weights(todrive + "eesn3000.h5")


# serialize weights to HDF5
disc.save_weights(todrive + "disc3000.h5")

print("Saved models to disk")
# Out:
# Saved models to disk

# %%
# load the models (EESN, UDSN, DISC)

udsn.load_weights(todrive + "udsn.h5")

eesn.load_weights(todrive + "eesn.h5")

disc.load_weights(todrive + "disc.h5")

print("Loaded models from disk")
# Out:
# Loaded models from disk

# %%
ix=np.random.randint(0, 1096, 1)
ILR=resized_list[ix]
IHR=src_list[ix]
Ibase=udsn(ILR)
ISR=eesn(Ibase)

plt.figure(figsize=(20, 80))

plt.subplot(1,4,1)
ILR=ILR*127.5+127.5
plt.imshow(ILR.reshape(128,128,3).astype('uint8'))
plt.title('LR')

plt.subplot(1,4,2)
Ibase1=Ibase*127.5+127.5
plt.imshow(np.array(Ibase1).reshape(256,256,3).astype('uint8'))
plt.title('Ibase')

plt.subplot(1,4,3)
ISR1=ISR*127.5+127.5
plt.imshow(np.array(ISR1).reshape(256,256,3).astype('uint8'))
plt.title('ISR')

plt.subplot(1,4,4)
plt.imshow((IHR*127.5+127.5).reshape(256,256,3).astype('uint8'))
plt.title('IHR')
# Out:
# Text(0.5, 1.0, 'IHR')

# %%
#vgg(Ibase)

# %%
Ibase*127.5+127.5
# Out:
# <tf.Tensor: shape=(1, 256, 256, 3), dtype=float32, numpy=
# array([[[[171.12415 ,  57.799927, 233.3677  ],
#          [ 59.722015,  53.44861 ,  82.36383 ],
#          [154.34471 ,  52.68966 , 180.59126 ],
#          ...,
#          [ 75.72571 ,  53.28528 ,  88.43997 ],
#          [ 63.05787 ,  81.206436,  67.731316],
#          [ 63.292137,  53.70392 ,  67.67514 ]],
#
#         [[221.60709 ,  96.18275 ,  65.43609 ],
#          [ 60.959007,  52.888947,  67.63507 ],
#          [216.10953 , 208.46918 ,  62.723892],
#          ...,
#          [ 62.748817,  53.564613,  67.17191 ],
#          [120.19813 ,  58.61068 ,  92.729866],
#          [ 62.738503,  53.611732,  67.603485]],
#
#         [[236.94193 , 166.53381 ,  88.93919 ],
#          [ 60.012863,  52.70272 , 152.86488 ],
#          [232.22989 ,  53.17414 , 122.29303 ],
#          ...,
#          [ 63.20777 ,  61.851807,  77.73239 ],
#          [ 62.904083,  84.77275 ,  81.522   ],
#          [ 63.239296,  53.705887,  67.934364]],
#
#         ...,
#
#         [[ 61.41825 , 225.01328 ,  66.68097 ],
#          [ 77.19726 ,  53.633354, 185.56233 ],
#          [ 62.33663 , 237.75883 ,  67.56413 ],
#          ...,
#          [ 66.04538 ,  53.03209 , 108.407074],
#          [ 62.700798, 120.62948 ,  67.21978 ],
#          [107.58166 ,  53.630676, 119.663704]],
#
#         [[151.3061  , 101.2978  , 120.007225],
#          [169.52484 ,  72.345924,  66.29404 ],
#          [ 76.27108 , 126.31192 , 142.56705 ],
#          ...,
#          [129.37971 ,  93.738625,  67.448074],
#          [ 63.313362,  53.7351  ,  97.411995],
#          [118.23039 ,  88.320595,  76.96295 ]],
#
#         [[ 61.84835 , 116.900795,  66.12387 ],
#          [158.1386  ,  65.761314, 142.31041 ],
#          [ 62.05979 , 107.6391  ,  65.70952 ],
#          ...,
#          [166.76639 ,  52.748947, 108.996124],
#          [ 61.93701 ,  95.46994 ,  66.382095],
#          [122.1786  ,  53.088684, 147.65201 ]]]], dtype=float32)>

# %%
ISR1
# Out:
# <tf.Tensor: shape=(1, 256, 256, 3), dtype=float32, numpy=
# array([[[[8.4241486e+00, 2.6151123e+00, 1.6810371e+01],
#          [2.5320573e+02, 2.5283667e+02, 2.5358743e+02],
#          [2.2199921e+01, 7.9496536e+00, 2.9335617e+01],
#          ...,
#          [2.1832176e+02, 2.0803882e+02, 2.2248169e+02],
#          [1.9534213e+02, 2.0291321e+02, 1.9757765e+02],
#          [2.4806044e+02, 2.4662823e+02, 2.4830658e+02]],
#
#         [[1.1846227e+02, 4.4766068e+01, 3.2404510e+01],
#          [2.5406793e+02, 2.5383484e+02, 2.5411813e+02],
#          [4.9209595e-01, 5.2210236e-01, 8.7394714e-02],
#          ...,
#          [1.7338329e+02, 1.6643851e+02, 1.7604347e+02],
#          [2.5466614e+01, 1.4084404e+01, 1.9276154e+01],
#          [2.2988083e+02, 2.2611469e+02, 2.3094334e+02]],
#
#         [[4.2500534e+00, 2.1380081e+00, 8.0572510e-01],
#          [2.3064609e+02, 2.2746486e+02, 2.4594916e+02],
#          [1.1422852e+01, 1.7112274e+00, 3.3972168e+00],
#          ...,
#          [1.4099672e+02, 1.3960463e+02, 1.5134418e+02],
#          [4.4113541e+01, 5.5282082e+01, 5.2707077e+01],
#          [2.3146106e+02, 2.2775226e+02, 2.3241769e+02]],
#
#         ...,
#
#         [[6.2594772e+01, 1.7240012e+02, 6.5722214e+01],
#          [1.3429752e+02, 1.1720538e+02, 2.0235410e+02],
#          [1.3080025e+01, 7.4548721e+01, 1.3997658e+01],
#          ...,
#          [1.0681184e+02, 9.8229012e+01, 1.3761597e+02],
#          [8.3044495e+01, 1.2347696e+02, 8.6160675e+01],
#          [1.2555500e+02, 8.8236984e+01, 1.3440697e+02]],
#
#         [[9.2289398e+01, 6.2909691e+01, 7.2549469e+01],
#          [1.9042885e+02, 1.2524831e+02, 1.2095848e+02],
#          [7.5262512e+01, 1.0908681e+02, 1.2060563e+02],
#          ...,
#          [5.3541939e+01, 3.9540817e+01, 2.9661507e+01],
#          [1.9691418e+02, 1.9049591e+02, 2.1240805e+02],
#          [1.6765492e+02, 1.4645235e+02, 1.3882990e+02]],
#
#         [[2.4526529e+02, 2.4923273e+02, 2.4560782e+02],
#          [8.9881409e+01, 4.1725685e+01, 7.9809486e+01],
#          [2.4786819e+02, 2.5029543e+02, 2.4806532e+02],
#          ...,
#          [7.9527496e+01, 2.9006416e+01, 4.8510796e+01],
#          [2.3365393e+02, 2.3910413e+02, 2.3446771e+02],
#          [1.3771031e+02, 8.9208481e+01, 1.5582848e+02]]]], dtype=float32)>

# %%
plt.imshow(np.array(Ibase*127.5+127.5).reshape(256,256,3).astype('uint8'))

# %%
Ibase.shape
# Out:
# TensorShape([1, 256, 256, 3])
